# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
# This notebook uses the wine quality dataset located at https://archive-beta.ics.uci.edu/dataset/186/wine+quality
Data = pd.read_csv("./winequality-red.csv",delimiter=";")

# %%
def RidgeNestedResample(alpha):
    inner = KFold(5, shuffle = True, random_state=42)
    outer = KFold(5, shuffle = True, random_state=42) 
    X = Data.loc[:,set.columns != "quality"]
    Y = Data["quality"]

    InnerMSE = []
    OuterMSE = []

    for i, (outtrain_index, outtest_index) in enumerate(outer.split(Data)):
        avgMSE = 0
        for v, (intrain_index, intest_index) in enumerate(inner.split(outtrain_index)):
            model = linear_model.Ridge(alpha = alpha)
            model.fit(X.iloc[intrain_index],Y.iloc[intrain_index])
            predictions = model.predict(X.iloc[intest_index])
            avgMSE += mean_squared_error(Y.iloc[intest_index],predictions)
        InnerMSE.append(avgMSE/5)

        model = linear_model.Ridge(alpha = alpha)
        model.fit(X.iloc[outtrain_index],Y.iloc[outtrain_index])
        predictions = model.predict(X.iloc[outtest_index])
        OuterMSE.append(mean_squared_error(Y.iloc[outtest_index],predictions))
    return InnerMSE,OuterMSE
            
alphas = [x/1000 for x in range(2000)]
Runs = []
for a in alphas:
    Runs.append(RidgeNestedResample(a))

# %%
for run in range(5):
    Inner1 = [Runs[x][0][run] for x in range(len(Runs))]
    best = Inner1.index(min((Inner1)))
    print(f"best inner {best} with {Runs[best][0][run]}")
    print(f"OuterMSE of this run {Runs[best][1][run]}")
# Out:
# best inner 455 with 0.4291921469066774
# OuterMSE of this run 0.39166712505669404
# best inner 455 with 0.4291921469066774
# OuterMSE of this run 0.4651694389310969
# best inner 455 with 0.4291921469066774
# OuterMSE of this run 0.48078449868954304
# best inner 455 with 0.4291921469066774
# OuterMSE of this run 0.4568551885005114
# best inner 305 with 0.4297739669045072
# OuterMSE of this run 0.3476732568775663

# %%
def TreeNestedResample(estimators,criterion,max_depth,min_samples_split,min_samples_leaf):
    inner = KFold(5, shuffle = True, random_state=42)
    outer = KFold(5, shuffle = True, random_state=42) 
    X = Data.loc[:,set.columns != "quality"]
    Y = Data["quality"]

    InnerMSE = []
    OuterMSE = []

    for i, (outtrain_index, outtest_index) in enumerate(outer.split(Data)):
        avgMSE = 0
        for v, (intrain_index, intest_index) in enumerate(inner.split(outtrain_index)):
            model = RandomForestClassifier(n_estimators=estimators,criterion=criterion,max_depth = max_depth,min_samples_split = min_samples_split, min_samples_leaf = min_samples_leaf)
            model.fit(X.iloc[intrain_index],Y.iloc[intrain_index])
            predictions = model.predict(X.iloc[intest_index])
            avgMSE += mean_squared_error(Y.iloc[intest_index],predictions)
        InnerMSE.append(avgMSE/5)

        model = RandomForestClassifier(n_estimators=estimators,criterion=criterion,max_depth = max_depth,min_samples_split = min_samples_split, min_samples_leaf = min_samples_leaf)
        model.fit(X.iloc[outtrain_index],Y.iloc[outtrain_index])
        predictions = model.predict(X.iloc[outtest_index])
        OuterMSE.append(mean_squared_error(Y.iloc[outtest_index],predictions))
    return InnerMSE,OuterMSE

# %%
TreeRuns = []
for a in range(100):
    estimators = np.random.randint(1,200)
    criterion = np.random.choice(["gini","entropy","log_loss"])
    max_depth = np.random.choice([None,np.random.randint(1,100)])
    min_samples_split = np.random.randint(2,3)
    min_samples_leaf = np.random.randint(1,3)

    print(f"Params: estimators = {estimators}, criterion = {criterion}, max_depth = {max_depth}, minsamplessplit = {min_samples_split}, minsamplesleaf = {min_samples_leaf}")
    TreeRuns.append((TreeNestedResample(estimators,criterion,max_depth,min_samples_split,min_samples_leaf),(estimators,criterion,max_depth,min_samples_split,min_samples_leaf)))
# Out:
# Params: estimators = 99, criterion = entropy, max_depth = 26, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 98, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 17, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 164, criterion = entropy, max_depth = 34, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 167, criterion = log_loss, max_depth = 43, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 138, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 148, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 189, criterion = log_loss, max_depth = 15, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 9, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 60, criterion = gini, max_depth = 20, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 38, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 175, criterion = entropy, max_depth = 61, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 188, criterion = gini, max_depth = 21, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 41, criterion = gini, max_depth = 73, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 194, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 110, criterion = gini, max_depth = 11, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 42, criterion = log_loss, max_depth = 92, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 101, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 61, criterion = log_loss, max_depth = 22, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 58, criterion = gini, max_depth = 27, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 39, criterion = gini, max_depth = 13, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 87, criterion = log_loss, max_depth = 30, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 8, criterion = log_loss, max_depth = 18, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 78, criterion = log_loss, max_depth = 11, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 186, criterion = entropy, max_depth = 76, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 36, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 47, criterion = log_loss, max_depth = 36, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 50, criterion = entropy, max_depth = 10, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 33, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 6, criterion = entropy, max_depth = 33, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 56, criterion = gini, max_depth = 95, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 77, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 17, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 183, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 21, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 169, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 26, criterion = log_loss, max_depth = 51, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 179, criterion = entropy, max_depth = 21, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 148, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 46, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 46, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 195, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 64, criterion = gini, max_depth = 68, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 138, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 2, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 184, criterion = gini, max_depth = 15, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 67, criterion = gini, max_depth = 71, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 116, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 11, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 146, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 102, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 84, criterion = gini, max_depth = 88, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 113, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 57, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 123, criterion = entropy, max_depth = 59, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 34, criterion = gini, max_depth = 16, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 153, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 42, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 71, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 185, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 95, criterion = entropy, max_depth = 29, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 46, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 94, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 13, criterion = log_loss, max_depth = 33, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 93, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 22, criterion = gini, max_depth = 54, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 126, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 129, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 51, criterion = gini, max_depth = 93, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 42, criterion = gini, max_depth = 70, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 29, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 50, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 84, criterion = entropy, max_depth = 87, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 24, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 9, criterion = gini, max_depth = 13, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 102, criterion = gini, max_depth = 98, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 113, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 65, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 122, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 156, criterion = entropy, max_depth = 83, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 29, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 60, criterion = entropy, max_depth = 6, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 120, criterion = gini, max_depth = 46, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 116, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 61, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 4, criterion = entropy, max_depth = 76, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 136, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 132, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 53, criterion = gini, max_depth = 5, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 6, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 155, criterion = entropy, max_depth = 70, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 188, criterion = gini, max_depth = 84, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 123, criterion = log_loss, max_depth = 12, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 154, criterion = log_loss, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 41, criterion = log_loss, max_depth = 6, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 5, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 1
# Params: estimators = 28, criterion = gini, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 75, criterion = entropy, max_depth = None, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 104, criterion = gini, max_depth = 1, minsamplessplit = 2, minsamplesleaf = 2
# Params: estimators = 122, criterion = log_loss, max_depth = 23, minsamplessplit = 2, minsamplesleaf = 1

# %%
print(TreeRuns[0])
for run in range(5):
    Inner1 = [TreeRuns[x][0][0][run] for x in range(len(TreeRuns))]
    best = Inner1.index(min((Inner1)))
    print(f"best inner {best} with {TreeRuns[best][0][0][run]}, with parameters {TreeRuns[best][1]}")
    print(f"OuterMSE of this run {TreeRuns[best][0][1][run]}")
# Out:
# (([0.41586703431372546, 0.42370710784313725, 0.4221262254901961, 0.4182322303921569, 0.40078125], [0.38125, 0.384375, 0.43125, 0.440625, 0.29153605015673983]), (99, 'entropy', 26, 2, 2))
# best inner 1 with 0.39551776960784313, with parameters (98, 'entropy', None, 2, 2)
# OuterMSE of this run 0.38125
# best inner 33 with 0.3986458333333333, with parameters (183, 'entropy', None, 2, 1)
# OuterMSE of this run 0.415625
# best inner 5 with 0.3885018382352941, with parameters (138, 'entropy', None, 2, 1)
# OuterMSE of this run 0.434375
# best inner 14 with 0.40019607843137256, with parameters (194, 'log_loss', None, 2, 2)
# OuterMSE of this run 0.428125
# best inner 5 with 0.37421875, with parameters (138, 'entropy', None, 2, 1)
# OuterMSE of this run 0.34169278996865204

# %%
def SVMNestedResample(regparam,kernel, degree ,gamma,coef0,shrinking):
    inner = KFold(5, shuffle = True, random_state=42)
    outer = KFold(5, shuffle = True, random_state=42) 
    X = Data.loc[:,set.columns != "quality"]
    Y = Data["quality"]

    InnerMSE = []
    OuterMSE = []

    for i, (outtrain_index, outtest_index) in enumerate(outer.split(Data)):
        avgMSE = 0
        for v, (intrain_index, intest_index) in enumerate(inner.split(outtrain_index)):
            model = SVC(C=regparam,kernel=kernel,degree=degree,gamma=gamma,coef0=coef0,shrinking=shrinking)
            model.fit(X.iloc[intrain_index],Y.iloc[intrain_index])
            predictions = model.predict(X.iloc[intest_index])
            avgMSE += mean_squared_error(Y.iloc[intest_index],predictions)
        InnerMSE.append(avgMSE/5)

        model = SVC(C=regparam,kernel=kernel,degree=degree,gamma=gamma,coef0=coef0,shrinking=shrinking)
        model.fit(X.iloc[outtrain_index],Y.iloc[outtrain_index])
        predictions = model.predict(X.iloc[outtest_index])
        OuterMSE.append(mean_squared_error(Y.iloc[outtest_index],predictions))
    return InnerMSE,OuterMSE

# %%
SVMRuns = []
for a in range(100):
    regparam = abs(np.random.normal(1,0.5))
    kernel = np.random.choice(["rbf","sigmoid"])
    degree = np.random.randint(1,3)
    gamma = np.random.choice(["scale","auto"])
    coef0 = np.random.random()*5
    shrinking = np.random.choice([True,False])

    print(f"Params: regparam = {regparam}, kernel = {kernel}, degree = {degree}, gamma = {gamma}, coef0 = {coef0}, shrinking = {shrinking}")
    SVMRuns.append((SVMNestedResample(regparam,kernel, degree ,gamma,coef0,shrinking),(regparam,kernel,degree,gamma,coef0,shrinking)))
# Out:
# Params: regparam = 1.3468714702287508, kernel = sigmoid, degree = 2, gamma = auto, coef0 = 2.219734824185645, shrinking = True
# Params: regparam = 0.48299169527411645, kernel = rbf, degree = 2, gamma = scale, coef0 = 0.174538268074666, shrinking = True
# Params: regparam = 1.3222698357254232, kernel = rbf, degree = 2, gamma = scale, coef0 = 2.6073155576943057, shrinking = True
# Params: regparam = 1.2075163222335759, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 2.002469810943654, shrinking = True
# Params: regparam = 1.0173168078000454, kernel = sigmoid, degree = 1, gamma = scale, coef0 = 3.6363113015963506, shrinking = True
# Params: regparam = 0.8459007932664172, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 0.34046798934666833, shrinking = False
# Params: regparam = 1.5621790282217904, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 0.20334529652524025, shrinking = False
# Params: regparam = 1.7997765413929554, kernel = rbf, degree = 2, gamma = scale, coef0 = 3.3563569619049223, shrinking = False
# Params: regparam = 1.1540202385573561, kernel = sigmoid, degree = 1, gamma = scale, coef0 = 3.95888352805676, shrinking = True
# Params: regparam = 0.7163269320021565, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 4.749101444923465, shrinking = True
# Params: regparam = 1.3418605965303632, kernel = rbf, degree = 2, gamma = scale, coef0 = 3.734781321095597, shrinking = False
# Params: regparam = 1.1789642386356491, kernel = rbf, degree = 1, gamma = auto, coef0 = 4.430567662863777, shrinking = True
# Params: regparam = 0.5941092480096565, kernel = sigmoid, degree = 1, gamma = scale, coef0 = 3.558298970343344, shrinking = False
# Params: regparam = 0.7464773630414895, kernel = rbf, degree = 1, gamma = scale, coef0 = 1.828515016571937, shrinking = True
# Params: regparam = 0.2929480764241035, kernel = sigmoid, degree = 1, gamma = scale, coef0 = 0.22480715350135516, shrinking = False
# Params: regparam = 1.6566474038262686, kernel = rbf, degree = 2, gamma = scale, coef0 = 4.637496465615795, shrinking = True
# Params: regparam = 0.6163482424975452, kernel = rbf, degree = 1, gamma = auto, coef0 = 2.677574597560699, shrinking = False
# Params: regparam = 0.44789573916356706, kernel = rbf, degree = 2, gamma = auto, coef0 = 2.7581219659469483, shrinking = False
# Params: regparam = 0.9762057046587159, kernel = rbf, degree = 1, gamma = auto, coef0 = 0.1457068640550352, shrinking = False
# Params: regparam = 1.9301111861295719, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 1.2992803992311481, shrinking = False
# Params: regparam = 0.8191560585978899, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 0.06204195422553238, shrinking = True
# Params: regparam = 0.8960683663514292, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 1.95651918364762, shrinking = True
# Params: regparam = 0.26552920809879144, kernel = sigmoid, degree = 1, gamma = scale, coef0 = 0.7265059963643378, shrinking = True
# Params: regparam = 1.097335837785394, kernel = sigmoid, degree = 1, gamma = scale, coef0 = 2.342999977723728, shrinking = True
# Params: regparam = 0.6913950209067603, kernel = rbf, degree = 1, gamma = scale, coef0 = 1.3759879662202583, shrinking = True
# Params: regparam = 1.3265445443766972, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 0.7146793574069688, shrinking = True
# Params: regparam = 1.423346357631853, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 1.0627181699019301, shrinking = True
# Params: regparam = 0.683154907302727, kernel = sigmoid, degree = 1, gamma = scale, coef0 = 4.204475822898809, shrinking = True
# Params: regparam = 0.8477653155079664, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 4.615092960450724, shrinking = False
# Params: regparam = 1.7181524814813596, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 3.648597038605279, shrinking = False
# Params: regparam = 1.1238220710298958, kernel = rbf, degree = 2, gamma = scale, coef0 = 0.918572383019654, shrinking = True
# Params: regparam = 0.573652031506966, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 4.07859108459969, shrinking = True
# Params: regparam = 0.8722491374460561, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 3.001867440333887, shrinking = False
# Params: regparam = 0.9298635016526836, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 4.88399496996273, shrinking = False
# Params: regparam = 1.1706947566181256, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 1.3653035200878545, shrinking = True
# Params: regparam = 1.381111688430253, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 2.0115121807109198, shrinking = True
# Params: regparam = 0.03942142579233421, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 0.8328113485012534, shrinking = True
# Params: regparam = 1.2363537913196565, kernel = sigmoid, degree = 1, gamma = scale, coef0 = 4.745663339640939, shrinking = False
# Params: regparam = 0.6777530701803975, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 2.5902984733231467, shrinking = True
# Params: regparam = 0.9702499265486363, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 2.983439028445583, shrinking = True
# Params: regparam = 0.9902003941146915, kernel = rbf, degree = 1, gamma = auto, coef0 = 4.50102441062516, shrinking = True
# Params: regparam = 0.7603420021849905, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 3.6225965535916105, shrinking = True
# Params: regparam = 0.07453244447944296, kernel = rbf, degree = 2, gamma = scale, coef0 = 3.8668266349580778, shrinking = False
# Params: regparam = 0.4800616299226703, kernel = rbf, degree = 2, gamma = auto, coef0 = 3.86342407607931, shrinking = True
# Params: regparam = 1.4176629996340642, kernel = rbf, degree = 2, gamma = scale, coef0 = 4.785890412278766, shrinking = False
# Params: regparam = 1.090627104120078, kernel = rbf, degree = 1, gamma = scale, coef0 = 1.8293030515553688, shrinking = True
# Params: regparam = 1.4776920010952042, kernel = rbf, degree = 2, gamma = auto, coef0 = 4.08422835921956, shrinking = True
# Params: regparam = 1.1138629915706386, kernel = rbf, degree = 1, gamma = scale, coef0 = 4.049348925076405, shrinking = False
# Params: regparam = 1.3681251453088423, kernel = rbf, degree = 1, gamma = auto, coef0 = 4.167417828945873, shrinking = True
# Params: regparam = 0.27207864018506556, kernel = rbf, degree = 1, gamma = auto, coef0 = 3.248309410469133, shrinking = True
# Params: regparam = 0.46362875622315713, kernel = sigmoid, degree = 2, gamma = auto, coef0 = 3.7058602597059003, shrinking = True
# Params: regparam = 0.8279096722217882, kernel = rbf, degree = 1, gamma = auto, coef0 = 4.5755730506067005, shrinking = False
# Params: regparam = 0.1632546772305743, kernel = rbf, degree = 1, gamma = auto, coef0 = 4.859951716611385, shrinking = False
# Params: regparam = 1.3957362956912307, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 1.5459561615229422, shrinking = False
# Params: regparam = 0.4137714370344866, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 3.061582804719438, shrinking = True
# Params: regparam = 0.5633688554795739, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 3.4433301192776606, shrinking = True
# Params: regparam = 0.3248389810891854, kernel = sigmoid, degree = 2, gamma = auto, coef0 = 3.8246205506251627, shrinking = False
# Params: regparam = 1.197558110102924, kernel = rbf, degree = 1, gamma = scale, coef0 = 2.5110624726620836, shrinking = True
# Params: regparam = 0.8969917180057666, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 2.997637630165036, shrinking = True
# Params: regparam = 0.3784555846705965, kernel = rbf, degree = 2, gamma = scale, coef0 = 0.0072433508553237935, shrinking = False
# Params: regparam = 0.5470600968062334, kernel = sigmoid, degree = 2, gamma = auto, coef0 = 4.7962262506759235, shrinking = True
# Params: regparam = 1.4824628408858587, kernel = rbf, degree = 2, gamma = auto, coef0 = 4.539278881102545, shrinking = False
# Params: regparam = 0.7485860348057531, kernel = rbf, degree = 2, gamma = auto, coef0 = 0.31853905156073836, shrinking = True
# Params: regparam = 1.6040735602424743, kernel = rbf, degree = 1, gamma = scale, coef0 = 4.712493968562866, shrinking = False
# Params: regparam = 1.5745235004797191, kernel = sigmoid, degree = 2, gamma = auto, coef0 = 2.3350637024441, shrinking = True
# Params: regparam = 1.4604646602350475, kernel = rbf, degree = 2, gamma = auto, coef0 = 2.0674885604881412, shrinking = True
# Params: regparam = 0.6350174255081573, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 0.46902501586405076, shrinking = False
# Params: regparam = 1.8702434265495402, kernel = rbf, degree = 2, gamma = auto, coef0 = 3.5957207591177487, shrinking = True
# Params: regparam = 1.3896324439907026, kernel = rbf, degree = 1, gamma = scale, coef0 = 4.776663122139546, shrinking = False
# Params: regparam = 1.5410804972490766, kernel = rbf, degree = 2, gamma = auto, coef0 = 3.255986620443151, shrinking = False
# Params: regparam = 1.3882311103254312, kernel = rbf, degree = 2, gamma = auto, coef0 = 3.208428708074866, shrinking = True
# Params: regparam = 1.1811661465719796, kernel = rbf, degree = 2, gamma = auto, coef0 = 0.46942119312165465, shrinking = False
# Params: regparam = 1.1155590388188892, kernel = sigmoid, degree = 1, gamma = scale, coef0 = 4.566815913466089, shrinking = False
# Params: regparam = 2.0116107834303776, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 1.1458923912651275, shrinking = True
# Params: regparam = 0.8453156865176126, kernel = rbf, degree = 1, gamma = scale, coef0 = 0.10084576794610944, shrinking = True
# Params: regparam = 1.047550987340111, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 1.234993695084673, shrinking = False
# Params: regparam = 0.7118388901960235, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 1.183185611666246, shrinking = True
# Params: regparam = 1.3834915837723227, kernel = rbf, degree = 1, gamma = scale, coef0 = 3.7232448459501666, shrinking = True
# Params: regparam = 0.3002176057289543, kernel = rbf, degree = 2, gamma = auto, coef0 = 1.8052716187974576, shrinking = True
# Params: regparam = 0.9506209182864015, kernel = rbf, degree = 2, gamma = auto, coef0 = 3.1048644166061052, shrinking = False
# Params: regparam = 1.1457578308677543, kernel = sigmoid, degree = 2, gamma = auto, coef0 = 1.242482764738131, shrinking = False
# Params: regparam = 0.4716841083226614, kernel = rbf, degree = 1, gamma = auto, coef0 = 3.818708061427049, shrinking = True
# Params: regparam = 1.2508513017988452, kernel = rbf, degree = 2, gamma = scale, coef0 = 2.4027241434165063, shrinking = False
# Params: regparam = 0.5283287562224451, kernel = rbf, degree = 1, gamma = auto, coef0 = 2.978791848825134, shrinking = True
# Params: regparam = 0.7451549112638394, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 1.7949082652562964, shrinking = True
# Params: regparam = 0.6140318573485213, kernel = sigmoid, degree = 2, gamma = scale, coef0 = 1.0808631209613306, shrinking = False
# Params: regparam = 2.0852368587115233, kernel = rbf, degree = 1, gamma = auto, coef0 = 2.295759065598482, shrinking = True
# Params: regparam = 1.653100646867003, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 3.539043530872324, shrinking = False
# Params: regparam = 0.617403575659528, kernel = sigmoid, degree = 1, gamma = scale, coef0 = 4.328440158523847, shrinking = False
# Params: regparam = 0.041833470295783104, kernel = rbf, degree = 1, gamma = auto, coef0 = 3.938411931258558, shrinking = True
# Params: regparam = 1.5338295862484936, kernel = sigmoid, degree = 1, gamma = scale, coef0 = 3.897365847227431, shrinking = False
# Params: regparam = 2.0144022742354393, kernel = rbf, degree = 2, gamma = scale, coef0 = 0.6533116562414282, shrinking = True
# Params: regparam = 0.10092777390242103, kernel = sigmoid, degree = 1, gamma = scale, coef0 = 0.18465568371847207, shrinking = True
# Params: regparam = 0.5938298169027949, kernel = rbf, degree = 2, gamma = scale, coef0 = 0.19467538219718084, shrinking = True
# Params: regparam = 0.9857081420647251, kernel = sigmoid, degree = 2, gamma = auto, coef0 = 3.8972170687686605, shrinking = True
# Params: regparam = 1.2709049774110834, kernel = rbf, degree = 1, gamma = scale, coef0 = 3.265400547896222, shrinking = False
# Params: regparam = 1.9903273742346332, kernel = rbf, degree = 2, gamma = auto, coef0 = 4.110088160942974, shrinking = True
# Params: regparam = 1.5368916721482524, kernel = sigmoid, degree = 1, gamma = auto, coef0 = 0.4478671062514239, shrinking = False
# Params: regparam = 0.615710802064211, kernel = rbf, degree = 1, gamma = auto, coef0 = 2.2110345774324616, shrinking = False
# Params: regparam = 1.546522807581253, kernel = rbf, degree = 2, gamma = auto, coef0 = 2.779700637817069, shrinking = False

# %%
print(SVMRuns[0])
for run in range(5):
    Inner1 = [SVMRuns[x][0][0][run] for x in range(len(SVMRuns))]
    best = Inner1.index(min((Inner1)))
    print(f"best inner {best} with {SVMRuns[best][0][0][run]}, with parameters {SVMRuns[best][1]}")
    print(f"OuterMSE of this run {SVMRuns[best][0][1][run]}")
# Out:
# (([1.1000643382352941, 1.1000643382352941, 1.1000643382352941, 1.1000643382352941, 1.10234375], [1.121875, 0.9875, 1.059375, 1.096875, 1.0156739811912225]), (1.3468714702287508, 'sigmoid', 2, 'auto', 2.219734824185645, True))
# best inner 69 with 0.6059129901960784, with parameters (1.5410804972490766, 'rbf', 2, 'auto', 3.255986620443151, False)
# OuterMSE of this run 0.671875
# best inner 69 with 0.6059129901960784, with parameters (1.5410804972490766, 'rbf', 2, 'auto', 3.255986620443151, False)
# OuterMSE of this run 0.634375
# best inner 69 with 0.6059129901960784, with parameters (1.5410804972490766, 'rbf', 2, 'auto', 3.255986620443151, False)
# OuterMSE of this run 0.590625
# best inner 69 with 0.6059129901960784, with parameters (1.5410804972490766, 'rbf', 2, 'auto', 3.255986620443151, False)
# OuterMSE of this run 0.609375
# best inner 46 with 0.6328125, with parameters (1.4776920010952042, 'rbf', 2, 'auto', 4.08422835921956, True)
# OuterMSE of this run 0.5924764890282131
